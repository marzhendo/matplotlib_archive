# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
decades = np.array([1980, 1990, 2000, 2010, 2020])
home_price = np.array([64600, 122900, 169000, 221800, 336900]) 
plt.figure()
plt.plot(decades, home_price, marker='o')
plt.show()
