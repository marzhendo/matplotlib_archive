# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
toppings = np.array(['Pepperoni', 'Cheese', 'Mushroom', 'Pineapple', 'Prosciutto', 'Artichoke'])
orders = np.array([40, 25, 20, 15, 4, 5])
explode = [0.1, 0, 0, 0, 0, 0]  # Explode the first slice (Pepperoni)
plt.pie(orders, labels=toppings, autopct='%1.1f%%', explode=explode)
plt.title('Pizza Toppings Distribution')
plt.show()

# %%
toppings = np.array(['Pepperoni', 'Cheese', 'Mushroom', 'Pineapple', 'Prosciutto', 'Artichoke'])
orders = np.array([40, 25, 20, 15, 4, 5])
explode = [0.1, 0, 0, 0.1, 0, 0]  # Explode the first slice (Pepperoni)
plt.pie(orders, labels=toppings, autopct='%1.1f%%', explode=explode)
plt.title('Pizza Toppings Distribution')
plt.show()
